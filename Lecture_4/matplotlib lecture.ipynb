# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# %matplotlib inline 
# включено по умолчанию
# встраивает картинки в ноутбук

# %%
plt.plot(range(10))

# %%
# %matplotlib notebook
# интерактивный режим
# можно увеличивать кусочки графика
# чтобы выключить интерактивный режим для графика, надо нажать на синюю кнопку выключения

# %%
plt.plot(range(10))
# Out:
# <div id='338731e3-df3a-4efb-a17d-50a61f9944ca'></div>
# <div id='3e1f0772-c24a-42cb-b5f8-b6975042a7a6'></div>

# %%
import matplotlib.animation as animation
import time

fig, ax = plt.subplots(figsize=(5,5))
ax.set_ylim(-1.1, 1.1)
ax.set_xlim(-1.1, 1.1)
ax.grid()
ax.set_aspect(1)
phi = np.linspace(0, 360, 61)
x = np.cos(np.radians(phi))
y = np.sin(np.radians(phi))
line, = ax.plot(x, y, 'b')
point, = ax.plot(x[0], y[0], '.r', ms=20)

def animate(i):
    # update the data
    #ax.x
    point.set_xdata(x[i])
    point.set_ydata(y[i])
    #ax.plot(x[i], y[i], '.r', ms=20)
    return point,

ani = animation.FuncAnimation(fig, animate, interval=120, frames=phi.shape[0],
                              repeat=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
# %matplotlib inline
# Out:
# Traceback (most recent call last):
#   File "C:\Users\maria\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 388, in process
#     proxy(*args, **kwargs)
#   File "C:\Users\maria\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 228, in __call__
#     return mtd(*args, **kwargs)
#   File "C:\Users\maria\Anaconda3\lib\site-packages\matplotlib\animation.py", line 1560, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
